# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x= np.array([4,11,15,21,28,34,39,35,47,55])
y= np.array([10,22,31,36,48,51,58,61,69,77])
z= np.array([92,83,89,56,61,56,48,41,26,19])
p= np.array([56,44,27,65,38,61,23,75,36,58])

# %% [markdown]
# #### Line Plot

# %%
plt.plot(x,y)

# %%
plt.plot(x,z)

# %%
plt.plot(x,p)

# %%
plt.title('My first plot')
plt.grid()
plt.xlim(0,60)
plt.ylim(0,100)
plt.xticks(range(0,61,5))
plt.yticks(range(0,101,5))
plt.xlabel('First value')
plt.ylabel('Second Value')
plt.plot(x,y)

# %%
plt.title('My first plot')
plt.grid()
plt.xlim(0,60)
plt.ylim(0,100)
plt.xticks(range(0,61,5))
plt.yticks(range(0,101,5))
plt.xlabel('First value')
plt.ylabel('Second Value')
plt.plot(x,y,color ='g')

# %%
plt.title('My first plot')
plt.grid()
plt.xlabel('First value')
plt.ylabel('Second Value')
plt.plot(x,y, color='#A29F12')

# %%
plt.title('My first plot')
plt.grid()
plt.xlabel('First value')
plt.ylabel('Second Value')
# markers: o . < > v * D +
plt.plot(x,y, color='#A29F12', marker='v')

# %%
plt.title('My first plot')
plt.grid()
plt.xlabel('First value')
plt.ylabel('Second Value')
# markers: o . < > v * D +
plt.plot(x,y, color='#A29F12', marker='v', lw=3, mfc='red', ms=10, ls=':')

# %%
plt.title('Comparison plot')
plt.grid()
plt.xlabel('First value')
plt.ylabel('Second Value')
plt.plot(x,y, color='#A29F12')
plt.plot(x,z, color='blue')

# %%
plt.title('Comparison plot')
plt.grid()
plt.xlabel('First value')
plt.ylabel('Second Value')
plt.plot(x,y, color='#A29F12', label='2022')
plt.plot(x,z, color='blue', label='2023')
plt.legend()

# %%
plt.subplot(2,1,1)
plt.grid()
plt.plot(x,y,color='green')
plt.subplot(2,1,2)
plt.grid()
plt.plot(x,z, color='cyan')

# %%
plt.subplot(1,2,1)
plt.grid()
plt.plot(x,y,color='green')
plt.subplot(1,2,2)
plt.grid()
plt.plot(x,z, color='cyan')

# %%
plt.subplot(2,1,1)
plt.grid()
plt.plot(x,y,color='green')
plt.subplot(2,1,2)
plt.grid()
plt.plot(x,z, color='cyan')
plt.subplot(2,1,1)
plt.grid()
plt.plot(x,p,color='blue')

# %%
plt.subplot(2,2,1)
plt.grid()
plt.plot(x,y,color='green')
plt.subplot(2,2,3)
plt.grid()
plt.plot(x,z, color='cyan')
plt.subplot(1,2,2)
plt.grid()
plt.plot(x,z, color='red')

# %%
plt.figure(figsize=(16,9))
plt.title('Comparison plot')
plt.grid()
plt.xlabel('First value')
plt.ylabel('Second Value')
plt.plot(x,y, color='#A29F12', label='2022')
plt.plot(x,z, color='blue', label='2023')
plt.legend()

# %%
plt.figure(figsize=(16,9))
plt.title('Comparison plot')
plt.grid()
plt.xlabel('First value')
plt.ylabel('Second Value')
plt.plot(x,y, color='#A29F12', label='2022')
plt.plot(x,z, color='blue', label='2023')
plt.legend()
plt.savefig('myplot.png')

# %% [markdown]
# ####SCATTER PLOT

# %%
plt.title('Scatter plot')
plt.grid()
plt.xlabel('First value')
plt.ylabel('Second Value')
plt.scatter(x,y, color='#A29F12', label='2022')

plt.legend()

# %%
import pandas as pd

# %%
mtcars = pd.read_csv('mtcars.csv')

# %%
plt.xlabel('weight of the car')
plt.ylabel('mileage of car')
plt.plot(mtcars['wt'],mtcars['mpg'])

# %%
plt.xlabel('weight of the car')
plt.ylabel('mileage of car')
plt.scatter(mtcars['wt'],mtcars['mpg'])

# %%
sna = pd.read_csv('Social_Network_Ads.csv')

# %%
sna
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
plt.xlabel('Age')
plt.ylabel('Salary')
plt.grid()
plt.plot(sna['Age'],sna['EstimatedSalary'])

# %%
c

# %%
new = pd.DataFrame(data=[[45,56000],[24,45000],[35,123000]],columns=['Age','EstimatedSalary'])
new
# Out:
#    Age  EstimatedSalary
# 0   45            56000
# 1   24            45000
# 2   35           123000

# %%
plt.xlabel('Age')
plt.ylabel('Salary')
plt.grid()
plt.scatter(sna['Age'],sna['EstimatedSalary'],c=sna['Purchased'])
plt.scatter(new['Age'],new['EstimatedSalary'],color='red',s=100)

# %%
#### Bar Plot

# %%
enrol = pd.DataFrame({
    'Students': [67,89,106,179,47,122,100],
    'Languages':['C','C++','Java','Python','R','PHP','JavaScript']
})

# %%
enrol
# Out:
#    Students   Languages
# 0        67           C
# 1        89         C++
# 2       106        Java
# 3       179      Python
# 4        47           R
# 5       122         PHP
# 6       100  JavaScript

# %%
plt.title('Student Enrollment for Training')
plt.xlabel('Languages')
plt.ylabel('Total Students')
plt.bar(enrol['Languages'],enrol['Students'], color='cyan')
# Out:
# <BarContainer object of 7 artists>

# %%
plt.title('Student Enrollment for Training')
plt.xlabel('Languages')
plt.ylabel('Total Students')
plt.bar(enrol['Languages'],enrol['Students'], color='cyan')
plt.plot(enrol['Languages'],enrol['Students'], marker = '*')

# %%
plt.title('Student Enrollment for Training')
plt.ylabel('Languages')
plt.xlabel('Total Students')
plt.barh(enrol['Languages'],enrol['Students'], color='cyan')
# Out:
# <BarContainer object of 7 artists>

# %%
enrol = pd.DataFrame({
    'Students': [67,89,106,179,47,122,100],
    'Languages':['C','C++','Java','Python','R','PHP','JavaScript'],
    'AvgMarks':[67.45,69.23,72.45,78.23,63.27,69.34,74.23]
})

# %%
enrol
# Out:
#    Students   Languages  AvgMarks
# 0        67           C     67.45
# 1        89         C++     69.23
# 2       106        Java     72.45
# 3       179      Python     78.23
# 4        47           R     63.27
# 5       122         PHP     69.34
# 6       100  JavaScript     74.23

# %%
plt.title('Student Enrollment for Training')
plt.xlabel('Languages')
plt.ylabel('Total Students')
plt.bar(enrol['Languages'],enrol['Students'], color='cyan',align='edge',width=0.3, label='Total Student')
plt.bar(enrol['Languages'],enrol['AvgMarks'], color='darkcyan', align= 'center', width=0.2 , label='AvgMarks')
plt.legend()

# %%
##3 pie chart

# %%
plt.figure(figsize=(6,6))
plt.title('% Share of Students')
plt.pie(enrol['Students'], labels=enrol['Languages'], autopct='%2.2f%%');

# %%
sna
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
plt.figure(figsize=(6,6))
plt.title('% Share of purchase')
plt.pie(sna['Purchased'], autopct='%2.2f%%');

# %%
sna['Purchased'].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
plt.pie(sna['Purchased'].value_counts(), autopct='%2.2f%%',labels=['Purchased','Not purchased']);

# %% [markdown]
# #### Doghnut Chart

# %%
my_circle = plt.Circle((0,0),0.7,color='white')

plt.pie(enrol['Students'], labels=enrol['Languages'], autopct='%2.2f%%');
p=plt.gcf()
p.gca().add_artist(my_circle)

# %%
pip install squarify
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.23ubuntu1'
# WARNING: Error parsing dependencies of python-debian: Invalid version: '0.1.36ubuntu1'
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import squarify

# %%
##### Change Color 

squarify.plot(sizes=enrol['Students'], label=enrol['Languages'],
              alpha=.5, color=['yellow','navy','cyan','blue','lightgreen','teal','grey']);

# %%
squarify.plot(sizes=enrol['Students'], label=enrol['Languages'],
              alpha=.5, color=['yellow','navy','cyan','blue','lightgreen','teal','grey']);
plt.axis('off');

# %% [markdown]
# ### Box Plot

# %%
plt.boxplot(sna['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f7bacdaad30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f7bacdaa0d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f7bacdaad90>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f7bacdae190>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f7bacdaeee0>],
#  'means': []}

# %%
plt.boxplot(mtcars, labels=mtcars.columns);

# %%
plt.boxplot(mtcars.iloc[:,5:], labels=mtcars.iloc[:,5:].columns);

# %% [markdown]
# ### Histogram

# %%
plt.title('Age frequencies')
plt.xticks(range(10,61,10))
plt.xlabel('Ages')
plt.ylabel('count')
plt.grid()
plt.hist(sna['Age'], bins=range(10,61,10),color = 'teal');

# %%
plt.figure(figsize=(16,9))
plt.title('Salary frequencies')
plt.xticks(range(15000,150001,10000))
plt.xlabel('Salary')
plt.ylabel('count')
plt.grid()
plt.hist(sna['EstimatedSalary'], bins=range(15000,150001,10000),color = 'teal');

# %%
### visualization using seaborn

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
iris= sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.jointplot(x='petal_length',y='petal_width', data=iris,hue='species');

# %%
sns.jointplot(x='sepal_length',y='sepal_width', data=iris,hue='species');

# %%
#### Pair plot

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris, hue='species')

# %%
### Histogram

# %%
sns.histplot(iris);

# %%
sns.histplot(iris['sepal_length'] , color='skyblue');

# %%
sns.histplot(iris['sepal_length'] , kde=True ,color='Yellow');

# %%
sns.displot(iris['sepal_width'])

# %%
sns.kdeplot(iris['petal_length'],color='maroon')
# Out:
# <Axes: xlabel='petal_length', ylabel='Density'>

# %% [markdown]
# ### Count Plot

# %%
sns.countplot(sna['Purchased']);

# %%
sns.countplot(iris['species']);

# %%
sns.countplot(mtcars['gear']);

# %%
sns.countplot(x);

# %%
x=['M','M','F','M','M','F','F','M','F','M','M','F','M','M','F',]
sns.countplot(x);

# %% [markdown]
# ### Bar Plot

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.countplot(titanic['sex'])
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
sns.countplot(titanic['class'])
# Out:
# <Axes: xlabel='count', ylabel='class'>

# %%
sns.barplot(x='sex', y='survived', hue = 'class',data = titanic)
# Out:
# <Axes: xlabel='sex', ylabel='survived'>
